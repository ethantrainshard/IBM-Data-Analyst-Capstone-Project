# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
# %pip install pandas
# %pip install beautifulsoup4
# %pip install requests
# %pip install lxml html5lib
import pandas as pd
from bs4 import BeautifulSoup
import requests
import lxml, html5lib
# Out:
# Requirement already satisfied: pandas in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from beautifulsoup4) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (4.9.3)
# Requirement already satisfied: html5lib in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
page = requests.get(url)
print(page.text)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
# <title>
# Salary survey results of programming languages
# </title>
# <style>
# table, th, td {
#   border: 1px solid black;
# }
# </style>
# </head>
#
# <body>
# <hr />
# <h2>Popular Programming Languages</h2>
# <hr />
# <p>Finding out which is the best language is a tough task. A programming language is created to solve a specific problem. A language which is good for task A may not be able to properly handle task B. Comparing programming language is never easy. What we can do, however, is find which is popular in the industry.</p>
# <p>There are many ways to find the popularity of a programming languages. Counting the number of google searchs for each language is a simple way to find the popularity. GitHub and StackOverflow also can give some good pointers.</p>
# <p>Salary surveys are a way to find out the programmings languages that are most in demand in the industry. Below table is the result of one such survey. When using any survey keep in mind that the results vary year on year.</p>
# <hr />
# <table>
# <tbody>
# <tr>
# <td>No.</td>
# <td>Language</td>
# <td>Created By</td>
# <td>Average Annual Salary</td>
# <td>Learning Difficulty</td>
# </tr>
# <tr>
# <td>1</td>
# <td>Python</td>
# <td>Guido van Rossum</td>
# <td>$114,383</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>2</td>
# <td>Java</td>
# <td>James Gosling</td>
# <td>$101,013</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>3</td>
# <td>R</td>
# <td>Robert Gentleman, Ross Ihaka</td>
# <td>$92,037</td>
# <td>Hard</td>
# </tr>
# <tr>
# <td>4</td>
# <td>Javascript</td>
# <td>Netscape</td>
# <td>$110,981</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>5</td>
# <td>Swift</td>
# <td>Apple</td>
# <td>$130,801</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>6</td>
# <td>C++</td>
# <td>Bjarne Stroustrup</td>
# <td>$113,865</td>
# <td>Hard</td>
# </tr>
# <tr>
# <td>7</td>
# <td>C#</td>
# <td>Microsoft</td>
# <td>$88,726</td>
# <td>Hard</td>
# </tr>
# <tr>
# <td>8</td>
# <td>PHP</td>
# <td>Rasmus Lerdorf</td>
# <td>$84,727</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>9</td>
# <td>SQL</td>
# <td>Donald D. Chamberlin, Raymond F. Boyce.</td>
# <td>$84,793</td>
# <td>Easy</td>
# </tr>
# <tr>
# <td>10</td>
# <td>Go</td>
# <td>Robert Griesemer, Ken Thompson, Rob Pike.</td>
# <td>$94,082</td>
# <td>Difficult</td>
# </tr>
# </tbody>
# </table>
# <hr />
# </body>
# </html>

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
results = soup.find("table")
# language_details = results.find_all("tr")
df = pd.read_html(str(results), flavor="html5lib")[0]

print(df)
# Out:
#       0           1                                          2  \
# 0   No.    Language                                 Created By
# 1     1      Python                           Guido van Rossum
# 2     2        Java                              James Gosling
# 3     3           R               Robert Gentleman, Ross Ihaka
# 4     4  Javascript                                   Netscape
# 5     5       Swift                                      Apple
# 6     6         C++                          Bjarne Stroustrup
# 7     7          C#                                  Microsoft
# 8     8         PHP                             Rasmus Lerdorf
# 9     9         SQL    Donald D. Chamberlin, Raymond F. Boyce.
# 10   10          Go  Robert Griesemer, Ken Thompson, Rob Pike.
#
#                         3                    4
# 0   Average Annual Salary  Learning Difficulty
# 1                $114,383                 Easy
# 2                $101,013                 Easy
# 3                 $92,037                 Hard
# 4                $110,981                 Easy
# 5                $130,801                 Easy
# 6                $113,865                 Hard
# 7                 $88,726                 Hard
# 8                 $84,727                 Easy
# 9                 $84,793                 Easy
# 10                $94,082            Difficult

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
# your code goes here
df.to_csv("popular-languages.csv")

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
