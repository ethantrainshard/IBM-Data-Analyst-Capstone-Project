# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
# %pip install seaborn
import pandas as pd
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11393       25136  I am a developer by profession      Yes
# 11394       25137  I am a developer by profession      Yes
# 11395       25138  I am a developer by profession      Yes
# 11396       25141  I am a developer by profession      Yes
# 11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# 3                                                  Never
# 4      Less than once a month but more than once per ...
# ...                                                  ...
# 11393                                              Never
# 11394                                              Never
# 11395                            Less than once per year
# 11396  Less than once a month but more than once per ...
# 11397  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 0      The quality of OSS and closed source software ...  Employed full-time
# 1      The quality of OSS and closed source software ...  Employed full-time
# 2      OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3      The quality of OSS and closed source software ...  Employed full-time
# 4      The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11393  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11394  The quality of OSS and closed source software ...  Employed full-time
# 11395  The quality of OSS and closed source software ...  Employed full-time
# 11396  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11397  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country Student  \
# 0       United States      No
# 1         New Zealand      No
# 2       United States      No
# 3      United Kingdom      No
# 4           Australia      No
# ...               ...     ...
# 11393   United States      No
# 11394          Poland      No
# 11395   United States      No
# 11396     Switzerland      No
# 11397  United Kingdom      No
#
#                                                  EdLevel  \
# 0               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1      Some college/university study without earning ...
# 2            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11393        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11394        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11395        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11396  Secondary school (e.g. American high school, G...
# 11397          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                           UndergradMajor  ...  \
# 0      Computer science, computer engineering, or sof...  ...
# 1      Computer science, computer engineering, or sof...  ...
# 2      Computer science, computer engineering, or sof...  ...
# 3                                                    NaN  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11393  Computer science, computer engineering, or sof...  ...
# 11394  Computer science, computer engineering, or sof...  ...
# 11395  Computer science, computer engineering, or sof...  ...
# 11396                                                NaN  ...
# 11397  A natural science (ex. biology, chemistry, phy...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2      Somewhat more welcome now than last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 11393   Just as welcome now as I felt last year
# 11394     A lot more welcome now than last year
# 11395     A lot more welcome now than last year
# 11396  Somewhat less welcome now than last year
# 11397   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                    NaN  23.0    Man    No
# 2      Tech articles written by other developers;Cour...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  26.0    Man    No
# 4      Tech articles written by other developers;Indu...  29.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11393  Tech articles written by other developers;Cour...  36.0    Man    No
# 11394  Tech articles written by other developers;Tech...  25.0    Man    No
# 11395  Tech articles written by other developers;Indu...  34.0    Man    No
# 11396                                                NaN  25.0    Man    No
# 11397  Tech articles written by other developers;Tech...  30.0    Man    No
#
#                      Sexuality                              Ethnicity  \
# 0      Straight / Heterosexual           White or of European descent
# 1                     Bisexual           White or of European descent
# 2      Straight / Heterosexual           White or of European descent
# 3      Straight / Heterosexual           White or of European descent
# 4      Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial
# ...                        ...                                    ...
# 11393  Straight / Heterosexual           White or of European descent
# 11394  Straight / Heterosexual           White or of European descent
# 11395  Straight / Heterosexual           White or of European descent
# 11396  Straight / Heterosexual           White or of European descent
# 11397                 Bisexual           White or of European descent
#
#       Dependents           SurveyLength                  SurveyEase
# 0             No  Appropriate in length                        Easy
# 1             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length                        Easy
# 3             No  Appropriate in length  Neither easy nor difficult
# 4             No  Appropriate in length                        Easy
# ...          ...                    ...                         ...
# 11393         No  Appropriate in length                   Difficult
# 11394         No  Appropriate in length  Neither easy nor difficult
# 11395        Yes               Too long                        Easy
# 11396         No  Appropriate in length                        Easy
# 11397         No  Appropriate in length                        Easy
#
# [11398 rows x 85 columns]

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
sns.displot(df, x="ConvertedComp")
# Out:
# /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
sns.displot(df, x='ConvertedComp', bins=10)
# Out:
# /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df["ConvertedComp"].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df["Gender"].value_counts()["Man"]
# Out:
# 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df_responder_woman = df[df["Gender"] == "Woman"]
df_responder_woman["ConvertedComp"].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df_age = df["Age"]
df_age.describe().loc[['min', '25%', '50%', '75%', 'max']]
# Out:
# min    16.0
# 25%    25.0
# 50%    29.0
# 75%    35.0
# max    99.0
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
# df_age.columns = ["Age"]
df_age
sns.displot(df, x="Age", bins=4)
# Out:
# /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
# %pip install matplotlib
import matplotlib.pyplot as plt
df_convertedcomp = df["ConvertedComp"]
df_convertedcomp

# fig = plt.figure(figsize =(10, 7))
# plt.boxplot(df_convertedcomp)
# plt.show()
# Out:
# Requirement already satisfied: matplotlib in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# 0         61000.0
# 1         95179.0
# 2         90000.0
# 3        455352.0
# 4         65277.0
#            ...
# 11393    130000.0
# 11394     19880.0
# 11395    105000.0
# 11396     80371.0
# 11397         NaN
# Name: ConvertedComp, Length: 11398, dtype: float64

# %%
# fig = plt.figure(figsize =(10, 7))
# plt.boxplot(df_convertedcomp)
# plt.show()
df["ConvertedComp"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
# %pip install numpy
import numpy as np

q3, q1 = np.percentile(df["ConvertedComp"], [75 ,25])
iqr = q3 - q1
iqr
# Out:
# Requirement already satisfied: numpy in /Users/ethangoh/.pyenv/versions/3.10.12/lib/python3.10/site-packages (1.25.2)
# Note: you may need to restart the kernel to use updated packages.
# nan

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
